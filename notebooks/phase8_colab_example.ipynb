# %% [markdown]
# # Phase 8 Colab quickstart
# This minimal notebook installs dependencies, runs the Phase 8 smoke test, and executes a reduced ablation grid on GPU. Set the runtime to **Python 3.10** and **GPU** before running.

# %%
# Install pinned dependencies (CUDA 12.1 Torch wheels) and the package itself
# %pip install -r requirements-colab.txt
# %pip install -e .

# %%
# Run the Phase 8 smoke test
# %pytest tests/test_phase8_smoke.py -vv

# %%
# Execute a reduced GPU ablation grid
# !python scripts/run_ablation_grid.py \
    --config configs/experiments/phase8.yaml \
    --datasets synthetic_heston \
    --ablation_names hirm_full,erm_baseline \
    --seeds 0 \
    --device cuda \
    --reduced
