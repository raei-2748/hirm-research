# %% [markdown]
# # HIRM Phase 9 Colab Demo
# Setup and mini-grid run.

# %%
# Install dependencies
# !pip install -q torch==2.4.1 pandas matplotlib PyYAML
# !pip install -q -e .

# %%
# Run a tiny grid (CPU friendly)
# !python scripts/run_experiment_grid.py --config configs/experiments/phase9.yaml \
 --datasets synthetic_heston \
 --methods erm_baseline,hirm_full \
 --seeds 0 \
 --device cpu \
 --reduced

# %%
# Summarize results
# !python analysis/phase9_analysis.py --root_dir results/phase9 --output_dir analysis_outputs/phase9_colab

# %%
import pandas as pd
summary = pd.read_csv('analysis_outputs/phase9_colab/summary.csv')
summary.head()
